# %% [markdown]
# # Semana 5 - Clase 2
# ## Temas Selectos Proceso Químicos: Análisis de Datos con Python

# %% [markdown]
# # **Análisis estadístico**

# %%
from IPython.display import IFrame

pdf_url = "https://raw.githubusercontent.com/marinlopabi/Temas_Selectos_PQ_26-I/refs/heads/main/Datos-IQ-Esta.pdf"
viewer = "https://drive.google.com/viewerng/viewer?embedded=true&url=" + pdf_url

IFrame(viewer, width=1000, height=900)
# Out:
#         <iframe
#             width="1000"
#             height="900"
#             src="https://drive.google.com/viewerng/viewer?embedded=true&url=https://raw.githubusercontent.com/marinlopabi/Temas_Selectos_PQ_26-I/refs/heads/main/Datos-IQ-Esta.pdf"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %% [markdown]
# # Dataset 📊 📈
#
# Columna de destilación generada a partir de un modelo matemático. Se han añadido características de datos atípicos, como ruido, valores atípicos y datos faltantes, para obtener las condiciones industriales en el conjunto de datos.

# %% [markdown]
# Se cuenta con 450 horas de operación con un muestreo de 0.1 horas.
#
#
# Este conjunto de datos se ha utilizado para la validación de sensores suaves y la validación de un nuevo algoritmo de selección de características.
#
#
#
# `Referencia:` Cote-Ballesteros, J. E., Grisales Palacios, V. H., y Rodriguez-Castellanos, J. E. (2022). Un algoritmo de selección de variables de enfoque híbrido basado en información mutua para aplicaciones de sensores blandos industriales basados en datos. Ciencia E Ingeniería Neogranadina, 32(1), 59–70. https://doi.org/10.18359/rcin.5644

# %% [markdown]
# # **Ejercicio**:
#
# - Abrir los datos contenidos en el GitHub con nombre **dataset_distill.csv**
# - Mostrar las primeras 5 filas
# - Identificar el nombre de las columnas

# %%
import pandas as pd

ruta='https://raw.githubusercontent.com/marinlopabi/Temas_Selectos_PQ_26-I/refs/heads/main/ARCHIVOS/dataset_distill.csv'
df = pd.read_csv(ruta, sep=";")
df.head()
# Out:
#    Pressure      T1      T2      T3      T4      T5      T6      T7      T8  \
# 0      1.01  350.89  350.95  351.01  351.08  351.16  351.26  351.38  351.54
# 1      1.01  350.86  350.91  350.96  351.02  351.09  351.17  351.28  351.43
# 2      1.01  350.85  350.89  350.93  350.99  351.05  351.13  351.23  351.37
# 3      1.01  350.84  350.88  350.92  350.97  351.03  351.11  351.21  351.34
# 4      1.01  350.83  350.87  350.91  350.96  351.02  351.09  351.18  351.31
#
#        T9  ...     T11     T12     T13     T14    L     V    D    B    F  \
# 0  351.78  ...  353.00  355.19  363.77  371.47  780  1040  260  340  600
# 1  351.66  ...  352.76  354.66  362.20  370.98  780  1040  260  340  600
# 2  351.58  ...  352.55  354.13  360.16  370.10  780  1040  260  340  600
# 3  351.53  ...  352.40  353.75  358.45  368.99  780  1040  260  340  600
# 4  351.49  ...  352.30  353.50  357.23  367.81  780  1040  260  340  600
#
#    Ethanol concentration
# 0                0.82076
# 1                0.83253
# 2                0.83953
# 3                0.84366
# 4                0.84622
#
# [5 rows x 21 columns]

# %%
df.columns
# Out:
# Index(['Pressure', 'T1', 'T2', 'T3', 'T4', 'T5', 'T6', 'T7', 'T8', 'T9', 'T10',
#        'T11', 'T12', 'T13', 'T14', 'L', 'V', 'D', 'B', 'F',
#        'Ethanol concentration'],
#       dtype='object')

# %%
df.columns = df.columns.str.strip().str.replace(" ", "_")
df.head()
# Out:
#    Pressure      T1      T2      T3      T4      T5      T6      T7      T8  \
# 0      1.01  350.89  350.95  351.01  351.08  351.16  351.26  351.38  351.54
# 1      1.01  350.86  350.91  350.96  351.02  351.09  351.17  351.28  351.43
# 2      1.01  350.85  350.89  350.93  350.99  351.05  351.13  351.23  351.37
# 3      1.01  350.84  350.88  350.92  350.97  351.03  351.11  351.21  351.34
# 4      1.01  350.83  350.87  350.91  350.96  351.02  351.09  351.18  351.31
#
#        T9  ...     T11     T12     T13     T14    L     V    D    B    F  \
# 0  351.78  ...  353.00  355.19  363.77  371.47  780  1040  260  340  600
# 1  351.66  ...  352.76  354.66  362.20  370.98  780  1040  260  340  600
# 2  351.58  ...  352.55  354.13  360.16  370.10  780  1040  260  340  600
# 3  351.53  ...  352.40  353.75  358.45  368.99  780  1040  260  340  600
# 4  351.49  ...  352.30  353.50  357.23  367.81  780  1040  260  340  600
#
#    Ethanol_concentration
# 0                0.82076
# 1                0.83253
# 2                0.83953
# 3                0.84366
# 4                0.84622
#
# [5 rows x 21 columns]

# %%
df.columns
# Out:
# Index(['Pressure', 'T1', 'T2', 'T3', 'T4', 'T5', 'T6', 'T7', 'T8', 'T9', 'T10',
#        'T11', 'T12', 'T13', 'T14', 'L', 'V', 'D', 'B', 'F',
#        'Ethanol_concentration'],
#       dtype='object')

# %% [markdown]
# ## 📊 Variables del conjunto de datos – Columna de destilación
#
# | No. | Variable                                      | Unidad              | Descripción general |
# |-----|----------------------------------------------|---------------------|---------------------|
# | 1   | Presión de la columna                        | bar                 | Presión de operación de la columna de destilación. |
# | 2   | Temperatura en cada plato                    | K                   | Temperatura registrada en cada etapa (plato) de la columna. |
# | 3   | Caudal de líquido                            | kmol/h              | Flujo molar de la fase líquida dentro de la columna. |
# | 4   | Caudal de vapor                              | kmol/h              | Flujo molar de la fase vapor dentro de la columna. |
# | 5   | Caudal de destilado                          | kmol/h              | Flujo molar del producto superior (destilado). |
# | 6   | Caudal de fondo                              | kmol/h              | Flujo molar del producto inferior (fondos). |
# | 7   | Caudal de alimentación                       | kmol/h              | Flujo molar de entrada a la columna. |
# | 8   | Concentración molar de etanol (salida)       | fracción molar (-)  | Composición molar de etanol en la corriente de salida. |

# %% [markdown]
# ## Estadistica descriptiva básica

# %%
df.describe()
# Out:
#            Pressure           T1           T2           T3           T4  \
# count  4.408000e+03  4408.000000  4408.000000  4408.000000  4408.000000
# mean   1.010000e+00   351.029049   351.409363   352.066202   352.828578
# std    1.141439e-13     0.334105     1.125225     2.671189     3.788418
# min    1.010000e+00   350.760000   350.770000   350.770000   350.790000
# 25%    1.010000e+00   350.820000   350.860000   350.900000   350.950000
# 50%    1.010000e+00   350.900000   350.990000   351.100000   351.260000
# 75%    1.010000e+00   351.080000   351.390000   351.822500   352.410000
# max    1.010000e+00   352.320000   356.030000   364.970000   368.600000
#
#                 T5           T6           T7           T8           T9  \
# count  4408.000000  4408.000000  4408.000000  4408.000000  4408.000000
# mean    353.910204   355.214270   356.453975   357.539902   358.484004
# std       4.986453     6.251028     7.119853     7.620257     7.882159
# min     350.800000   350.820000   350.860000   350.910000   351.000000
# 25%     351.000000   351.070000   351.160000   351.280000   351.440000
# 50%     351.475000   351.840000   352.370000   352.930000   353.740000
# 75%     353.740000   356.867500   361.640000   364.750000   366.880000
# max     369.060000   372.570000   372.970000   373.010000   373.010000
#
#                T10          T11          T12          T13          T14  \
# count  4408.000000  4408.000000  4408.000000  4408.000000  4408.000000
# mean    359.301298   360.048650   360.884025   364.367117   367.717250
# std       7.979290     7.899189     7.604026     8.563034     6.639423
# min     351.160000   351.500000   352.430000   353.150000   354.520000
# 25%     351.720000   352.220000   353.320000   354.750000   362.920000
# 50%     354.600000   356.785000   361.470000   370.745000   372.810000
# 75%     367.420000   367.522500   367.910000   372.440000   373.010000
# max     373.010000   373.010000   373.010000   373.060000   373.070000
#
#                  D            B            F  Ethanol_concentration
# count  4408.000000  4408.000000  4408.000000            4408.000000
# mean    251.823956   293.411978   545.235935               0.792205
# std      71.048000   108.550994   119.192840               0.076441
# min     150.000000    90.000000   350.000000               0.538190
# 25%     150.000000   200.000000   350.000000               0.761890
# 50%     260.000000   320.000000   600.000000               0.817520
# 75%     260.000000   352.500000   600.000000               0.850280
# max     350.000000   450.000000   650.000000               0.891760

# %% [markdown]
# ¿Por qué no parecen L y V?

# %%
df.dtypes
# Out:
# Pressure                 float64
# T1                       float64
# T2                       float64
# T3                       float64
# T4                       float64
# T5                       float64
# T6                       float64
# T7                       float64
# T8                       float64
# T9                       float64
# T10                      float64
# T11                      float64
# T12                      float64
# T13                      float64
# T14                      float64
# L                         object
# V                         object
# D                          int64
# B                          int64
# F                          int64
# Ethanol_concentration    float64
# dtype: object

# %%
df["L"] = pd.to_numeric(df["L"], errors="coerce")
df["V"] = pd.to_numeric(df["V"], errors="coerce")

# %%
df.describe()
# Out:
#            Pressure           T1           T2           T3           T4  \
# count  4.408000e+03  4408.000000  4408.000000  4408.000000  4408.000000
# mean   1.010000e+00   351.029049   351.409363   352.066202   352.828578
# std    1.141439e-13     0.334105     1.125225     2.671189     3.788418
# min    1.010000e+00   350.760000   350.770000   350.770000   350.790000
# 25%    1.010000e+00   350.820000   350.860000   350.900000   350.950000
# 50%    1.010000e+00   350.900000   350.990000   351.100000   351.260000
# 75%    1.010000e+00   351.080000   351.390000   351.822500   352.410000
# max    1.010000e+00   352.320000   356.030000   364.970000   368.600000
#
#                 T5           T6           T7           T8           T9  ...  \
# count  4408.000000  4408.000000  4408.000000  4408.000000  4408.000000  ...
# mean    353.910204   355.214270   356.453975   357.539902   358.484004  ...
# std       4.986453     6.251028     7.119853     7.620257     7.882159  ...
# min     350.800000   350.820000   350.860000   350.910000   351.000000  ...
# 25%     351.000000   351.070000   351.160000   351.280000   351.440000  ...
# 50%     351.475000   351.840000   352.370000   352.930000   353.740000  ...
# 75%     353.740000   356.867500   361.640000   364.750000   366.880000  ...
# max     369.060000   372.570000   372.970000   373.010000   373.010000  ...
#
#                T11          T12          T13          T14             L  \
# count  4408.000000  4408.000000  4408.000000  4408.000000   4150.000000
# mean    360.048650   360.884025   364.367117   367.717250   2229.772289
# std       7.899189     7.604026     8.563034     6.639423   5600.401081
# min     351.500000   352.430000   353.150000   354.520000     75.000000
# 25%     352.220000   353.320000   354.750000   362.920000    450.000000
# 50%     356.785000   361.470000   370.745000   372.810000    780.000000
# 75%     367.522500   367.910000   372.440000   373.010000   1050.000000
}")
# Out:
# <style type="text/css">
# </style>
# <table id="T_83908" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_83908_level0_col0" class="col_heading level0 col0" >Pressure</th>
#       <th id="T_83908_level0_col1" class="col_heading level0 col1" >T1</th>
#       <th id="T_83908_level0_col2" class="col_heading level0 col2" >T2</th>
#       <th id="T_83908_level0_col3" class="col_heading level0 col3" >T3</th>
#       <th id="T_83908_level0_col4" class="col_heading level0 col4" >T4</th>
#       <th id="T_83908_level0_col5" class="col_heading level0 col5" >T5</th>
#       <th id="T_83908_level0_col6" class="col_heading level0 col6" >T6</th>
#       <th id="T_83908_level0_col7" class="col_heading level0 col7" >T7</th>
#       <th id="T_83908_level0_col8" class="col_heading level0 col8" >T8</th>
#       <th id="T_83908_level0_col9" class="col_heading level0 col9" >T9</th>
#       <th id="T_83908_level0_col10" class="col_heading level0 col10" >T10</th>
#       <th id="T_83908_level0_col11" class="col_heading level0 col11" >T11</th>
#       <th id="T_83908_level0_col12" class="col_heading level0 col12" >T12</th>
#       <th id="T_83908_level0_col13" class="col_heading level0 col13" >T13</th>
#       <th id="T_83908_level0_col14" class="col_heading level0 col14" >T14</th>
#       <th id="T_83908_level0_col15" class="col_heading level0 col15" >L</th>
#       <th id="T_83908_level0_col16" class="col_heading level0 col16" >V</th>
#       <th id="T_83908_level0_col17" class="col_heading level0 col17" >D</th>
#       <th id="T_83908_level0_col18" class="col_heading level0 col18" >B</th>
#       <th id="T_83908_level0_col19" class="col_heading level0 col19" >F</th>
#       <th id="T_83908_level0_col20" class="col_heading level0 col20" >Ethanol_concentration</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_83908_level0_row0" class="row_heading level0 row0" >count</th>
#       <td id="T_83908_row0_col0" class="data row0 col0" >4408.0000</td>
#       <td id="T_83908_row0_col1" class="data row0 col1" >4408.0000</td>
#       <td id="T_83908_row0_col2" class="data row0 col2" >4408.0000</td>
#       <td id="T_83908_row0_col3" class="data row0 col3" >4408.0000</td>
#       <td id="T_83908_row0_col4" class="data row0 col4" >4408.0000</td>
#       <td id="T_83908_row0_col5" class="data row0 col5" >4408.0000</td>
#       <td id="T_83908_row0_col6" class="data row0 col6" >4408.0000</td>
#       <td id="T_83908_row0_col7" class="data row0 col7" >4408.0000</td>
#       <td id="T_83908_row0_col8" class="data row0 col8" >4408.0000</td>
#       <td id="T_83908_row0_col9" class="data row0 col9" >4408.0000</td>
#       <td id="T_83908_row0_col10" class="data row0 col10" >4408.0000</td>
#       <td id="T_83908_row0_col11" class="data row0 col11" >4408.0000</td>
#       <td id="T_83908_row0_col12" class="data row0 col12" >4408.0000</td>
#       <td id="T_83908_row0_col13" class="data row0 col13" >4408.0000</td>
#       <td id="T_83908_row0_col14" class="data row0 col14" >4408.0000</td>
#       <td id="T_83908_row0_col15" class="data row0 col15" >4150.0000</td>
#       <td id="T_83908_row0_col16" class="data row0 col16" >4150.0000</td>
#       <td id="T_83908_row0_col17" class="data row0 col17" >4408.0000</td>
#       <td id="T_83908_row0_col18" class="data row0 col18" >4408.0000</td>
#       <td id="T_83908_row0_col19" class="data row0 col19" >4408.0000</td>
#       <td id="T_83908_row0_col20" class="data row0 col20" >4408.0000</td>
#     </tr>
#     <tr>
#       <th id="T_83908_level0_row1" class="row_heading level0 row1" >mean</th>
#       <td id="T
level0_row3" class="row_heading level0 row3" >min</th>
#       <td id="T_83908_row3_col0" class="data row3 col0" >1.0100</td>
#       <td id="T_83908_row3_col1" class="data row3 col1" >350.7600</td>
#       <td id="T_83908_row3_col2" class="data row3 col2" >350.7700</td>
#       <td id="T_83908_row3_col3" class="data row3 col3" >350.7700</td>
#       <td id="T_83908_row3_col4" class="data row3 col4" >350.7900</td>
#       <td id="T_83908_row3_col5" class="data row3 col5" >350.8000</td>
#       <td id="T_83908_row3_col6" class="data row3 col6" >350.8200</td>
#       <td id="T_83908_row3_col7" class="data row3 col7" >350.8600</td>
#       <td id="T_83908_row3_col8" class="data row3 col8" >350.9100</td>
#       <td id="T_83908_row3_col9" class="data row3 col9" >351.0000</td>
#       <td id="T_83908_row3_col10" class="data row3 col10" >351.1600</td>
#       <td id="T_83908_row3_col11" class="data row3 col11" >351.5000</td>
#       <td id="T_83908_row3_col12" class="data row3 col12" >352.4300</td>
#       <td id="T_83908_row3_col13" class="data row3 col13" >353.1500</td>
#       <td id="T_83908_row3_col14" class="data row3 col14" >354.5200</td>
#       <td id="T_83908_row3_col15" class="data row3 col15" >75.0000</td>
#       <td id="T_83908_row3_col16" class="data row3 col16" >225.0000</td>
#       <td id="T_83908_row3_col17" class="data row3 col17" >150.0000</

# %% [markdown]
# Trabajaremos con las temperaturas.
#
#
# ##**Ejercicio**:
#
# Armar un nuevo dataframe con los valores correspondientes con las temperaturas.

# %%
tem=df[['T1', 'T2', 'T3', 'T4', 'T5', 'T6', 'T7', 'T8', 'T9', 'T10', 'T11', 'T12','T13', 'T14']]
tem.head()
# Out:
#        T1      T2      T3      T4      T5      T6      T7      T8      T9  \
# 0  350.89  350.95  351.01  351.08  351.16  351.26  351.38  351.54  351.78
# 1  350.86  350.91  350.96  351.02  351.09  351.17  351.28  351.43  351.66
# 2  350.85  350.89  350.93  350.99  351.05  351.13  351.23  351.37  351.58
# 3  350.84  350.88  350.92  350.97  351.03  351.11  351.21  351.34  351.53
# 4  350.83  350.87  350.91  350.96  351.02  351.09  351.18  351.31  351.49
#
#       T10     T11     T12     T13     T14
# 0  352.18  353.00  355.19  363.77  371.47
# 1  352.03  352.76  354.66  362.20  370.98
# 2  351.91  352.55  354.13  360.16  370.10
# 3  351.83  352.40  353.75  358.45  368.99
# 4  351.78  352.30  353.50  357.23  367.81

# %% [markdown]
# # Asimetría

# %% [markdown]
# ## Coeficiente de asimetría de Fisher
#
# El coeficiente de asimetría de Fisher es un coeficiente que permite calcular la asimetría de una distribución.
# Es decir, el coeficiente de asimetría sirve para determinar si una función es asimétrica positiva, asimétrica negativa o simétrica.
#
# Dada una muestra $$\{x_1, x_2, \ldots, x_n\}, $$ la fórmula del coeficiente de asimetría de Fisher es:
#
# $$
# \gamma_1 = \frac{\sum_{i=1}^{n}(x_i - \bar{x})^3}{n s^3}
# $$
#
# Donde $ \bar{x} $ y  s  son la media y la desviación estándar muestrales.
#
#
#
# *   $
# \gamma_1 >0 $ la distribución es asimétrica positiva. (cola a la derecha)
# *    $
# \gamma_1 < 0 $ la distribución es asimétrica negativa. (cola a la izquierda)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
asimetria= tem.skew()

print("\nAsimetría de Fisher:\n")
print(asimetria)
# Out:
# Asimetría de Fisher:
#
# T1     2.492693
# T2     3.072963
# T3     3.372123
# T4     2.757204
# T5     1.929362
# T6     1.453837
# T7     1.103980
# T8     0.833737
# T9     0.620700
# T10    0.461485
# T11    0.340554
# T12    0.237096
# T13   -0.232901
# T14   -0.786807
# dtype: float64

# %% [markdown]
# # Curtosis (Kurtosis)
#
# La **curtosis (Kurtosis)** describe el grado en que las colas de una distribución difieren de las colas de una distribución normal.
# En otras palabras, mide qué tan **afilada o achatada** es la distribución en comparación con la normal.

# %% [markdown]
# Python (a través de *pandas*, *numpy* y *scipy*) calcula la **curtosis de Fisher**, también conocida como **exceso de curtosis**, mediante la siguiente fórmula:
#
# $$
# K = \frac{n(n+1)}{(n-1)(n-2)(n-3)}
# \sum_{i=1}^{n}\left( \frac{x_i - \bar{x}}{s} \right)^4
# - \frac{3(n-1)^2}{(n-2)(n-3)}
# $$
#
# Donde:
# - $ K $ es la curtosis (exceso de curtosis),
# - $ \bar{x} $ es la media muestral,
# - $ s $ es la desviación estándar muestral,
# - $ n $ es el tamaño de la muestra.

# %% [markdown]
# ## Interpretación del coeficiente de curtosis en Python
#
# | Tipo de curtosis | Valor de \( K \) (exceso de curtosis) | Características |
# |------------------|----------------------------------------|-----------------|
# | **Leptocúrtica** | \( K > 0 \) | Colas más pesadas y un pico más alto y estrecho que la normal. |
# | **Mesocúrtica**  | \( K = 0 \) | Similar a la distribución normal (curtosis estándar). |
# | **Platicúrtica** | \( K < 0 \) | Colas más ligeras y un pico más achatado que la normal. |
#
# En esta definición, la **distribución normal** tiene \( K = 0 \).
#
#
#
#
# ---
#
# Forma general de las distribuciones según su curtosis:
#
# - **Leptocúrtica** → colas más gruesas (valores extremos más probables).
# - **Mesocúrtica** → comportamiento normal.
# - **Platicúrtica** → colas más ligeras (valores extremos menos probables).
#
# $$
# \text{Leptocúrtica } > \text{ Mesocúrtica } > \text{ Platicúrtica}
# $$

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
curtosis = tem.kurt()

print("\nCurtosis de Fisher:\n")
print(curtosis)
# Out:
# Curtosis de Fisher:
#
# T1      6.116531
# T2      8.893402
# T3     11.176225
# T4      7.216824
# T5      2.512210
# T6      0.679761
# T7     -0.326081
# T8     -0.907161
# T9     -1.250669
# T10    -1.442167
# T11    -1.534859
# T12    -1.579903
# T13    -1.851379
# T14    -0.956866
# dtype: float64

# %%
import matplotlib.pyplot as plt

tem.hist(bins=20, figsize=(14,10))
plt.tight_layout()
plt.show()

# %% [markdown]
# Mapa de colores https://python-charts.com/es/colores/

# %% [markdown]
# #**Histograma completo**

# %%
# --- 1. Calcular curtosis de Fisher ---
curtosis = tem.kurt()
# --- 2. Crear los histogramas ---
columnas = tem.columns
plt.figure(figsize=(15, 16))

for i, col in enumerate(columnas, 1):
    plt.subplot(4, 4, i)  # 4 filas, 4 columnas de gráficos
    plt.hist(tem[col], bins=20, color='skyblue', edgecolor='black')
    plt.title(f"{col}\nCurtosis: {curtosis[col]:.2f}", fontsize=12)
    plt.xlabel(col)
    plt.ylabel('Frecuencia')
#plt.suptitle("Distribución de temperaturas y su curtosis (Fisher)", fontsize=16)
plt.tight_layout()
#plt.savefig("histogramas.png", dpi=300, bbox_inches="tight")
plt.show()

# %%
cols_num = tem.select_dtypes(include="number")
cols_num.plot(kind="box", figsize=(14,6), grid=True)

plt.xticks(rotation=45, ha="right")
plt.ylabel("Temperatura (K)")
plt.tight_layout()
plt.show()

# %% [markdown]
# ¿No se ven datos atípicos o no existen?
